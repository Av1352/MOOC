# %% [markdown]
# <a href="https://colab.research.google.com/github/Av1352/MOOC/blob/main/MOOC_Assignment_5_(RA1911026040048).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
myfile=pd.read_csv("/content/FuelConsumption.csv")
myfile.head()
print(myfile)
print(type(myfile))
# Out:
#       MODELYEAR   MAKE  ... FUELCONSUMPTION_COMB_MPG CO2EMISSIONS
# 0          2014  ACURA  ...                       33          196
# 1          2014  ACURA  ...                       29          221
# 2          2014  ACURA  ...                       48          136
# 3          2014  ACURA  ...                       25          255
# 4          2014  ACURA  ...                       27          244
# ...         ...    ...  ...                      ...          ...
# 1062       2014  VOLVO  ...                       24          271
# 1063       2014  VOLVO  ...                       25          264
# 1064       2014  VOLVO  ...                       24          271
# 1065       2014  VOLVO  ...                       25          260
# 1066       2014  VOLVO  ...                       22          294
#
# [1067 rows x 13 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
myfile.dtypes
# Out:
# MODELYEAR                     int64
# MAKE                         object
# MODEL                        object
# VEHICLECLASS                 object
# ENGINESIZE                  float64
# CYLINDERS                     int64
# TRANSMISSION                 object
# FUELTYPE                     object
# FUELCONSUMPTION_CITY        float64
# FUELCONSUMPTION_HWY         float64
# FUELCONSUMPTION_COMB        float64
# FUELCONSUMPTION_COMB_MPG      int64
# CO2EMISSIONS                  int64
# dtype: object

# %%
myfile.shape
# Out:
# (1067, 13)

# %%
plt.scatter(myfile['MAKE'],myfile['MODEL'])
plt.show()

# %%
x=myfile['MAKE']
y=myfile['ENGINESIZE']

plt.xlabel('MAKE',fontsize=15)
plt.ylabel('ENGINESIZE',fontsize=15)
plt.bar(x,y)
plt.title("Bar Chart")

plt.show()

# %%
plt.xlabel('ENGINESIZE',fontsize=15)
plt.ylabel('CYLINDERS',fontsize=15)
plt.title('Line Graph')
plt.scatter(x,y)
plt.plot(x,y)
plt.show()
